# %% [markdown]
# <center> <h1> <font color='orange'> PYTHON EXAM <font> </h1> </center>

# %% [markdown]
# <h2><font color='blue'> NAME: GOLNOOSH TOOSI </font></h2>

# %% [markdown]
# <h2><font color='blue'> LU# : 20558659 </font></h2>

# %% [markdown]
# <h3><font color='RED'>QUESTION NUMBER 2 : USA POPULATION </font></h3>

# %%
# For this question I have downloaded the data from the followng website.

# %%
# "https://www2.census.gov/programs-surveys/popest/datasets/2010-2020/national/totals/" #

# %%
#Import libraries 
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
path = 'C:\\pytest'
os.chdir (path)
df = pd.read_csv('nst-est2020-alldata.csv')
df
# Out:
#     SUMLEV REGION DIVISION  STATE                  NAME  CENSUS2010POP  \
# 0       10      0        0      0         United States      308745538
# 1       20      1        0      0      Northeast Region       55317240
# 2       20      2        0      0        Midwest Region       66927001
# 3       20      3        0      0          South Region      114555744
# 4       20      4        0      0           West Region       71945553
# 5       40      3        6      1               Alabama        4779736
# 6       40      4        9      2                Alaska         710231
# 7       40      4        8      4               Arizona        6392017
# 8       40      3        7      5              Arkansas        2915918
# 9       40      4        9      6            California       37253956
# 10      40      4        8      8              Colorado        5029196
# 11      40      1        1      9           Connecticut        3574097
# ...

# %%
first = df.iloc[0]
first
# Out:
# SUMLEV                    10
# REGION                     0
# DIVISION                   0
# STATE                      0
# NAME           United States
#                    ...
# RNETMIG2016          3.30848
# RNETMIG2017          2.92626
# RNETMIG2018          2.20833
# RNETMIG2019          1.73586
# RNETMIG2020          1.45035
# Name: 0, Length: 166, dtype: object

# %%
second = first.iloc[7:16]
second
# Out:
# POPESTIMATE2010    309327143
# POPESTIMATE2011    311583481
# POPESTIMATE2012    313877662
# POPESTIMATE2013    316059947
# POPESTIMATE2014    318386329
# POPESTIMATE2015    320738994
# POPESTIMATE2016    323071755
# POPESTIMATE2017    325122128
# POPESTIMATE2018    326838199
# Name: 0, dtype: object

# %%
second.columns = ['year']
second
# Out:
# POPESTIMATE2010    309327143
# POPESTIMATE2011    311583481
# POPESTIMATE2012    313877662
# POPESTIMATE2013    316059947
# POPESTIMATE2014    318386329
# POPESTIMATE2015    320738994
# POPESTIMATE2016    323071755
# POPESTIMATE2017    325122128
# POPESTIMATE2018    326838199
# Name: 0, dtype: object

# %%
year = ['POPESTIMATE2010', 'POPESTIMATE2011', 'POPESTIMATE2012', 'POPESTIMATE2013', 'POPESTIMATE2014','POPESTIMATE2015','POPESTIMATE2016','POPESTIMATE2017','POPESTIMATE2018','POPESTIMATE2019','POPESTIMATE2020']
population = [309327143,311583481 ,313877662 ,316059947 ,318386329 , 320738994,323071755 ,325122128 ,326838199,328329953, 329484123]
plt.plot(year, population, color = 'red')
